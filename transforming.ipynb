# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the dataset
df = pd.read_csv('gdp_df.csv')
df.head() # display the first 5 rows of the dataset
# Out:
#   Country Name Country Code        Series Name     1999 [YR1999]  \
# 0  Afghanistan          AFG  GDP (current US$)                ..
# 1  Afghanistan          AFG  Population, total          19262847
# 2      Albania          ALB  GDP (current US$)  3212121650.97755
# 3      Albania          ALB  Population, total           3108778
# 4      Algeria          DZA  GDP (current US$)  48640671734.9711
#
#       2000 [YR2000]     2001 [YR2001]     2002 [YR2002]     2003 [YR2003]  \
# 0  3521418059.92345  2813571753.87253  3825701438.99963  4520946818.54581
# 1          19542982          19688632          21000256          22645130
# 2  3480355258.04122   3922100793.5403  4348068242.19512  5611496257.14231
# 3           3089027           3060173           3051010           3039616
# 4  54790398570.3282  59413400923.6364  61516103406.1688  73482264190.9245
#
#       2004 [YR2004]     2005 [YR2005]  ...     2014 [YR2014]  \
# 0  5224896718.67782  6203256538.70967  ...  20497128555.6972
# 1          23553551          24411191  ...          32716210
# 2  7184685781.51876  8052077248.14638  ...  13228147516.1168
# 3           3026939           3011487  ...           2889104
# 4  91913680985.1708  107046618669.707  ...   238942664192.59
#
#       2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# 0  19134221644.7325  18116572395.0772  18753456497.8159  18053222687.4126
# 1          33753499          34636207          35643418          36686784
# 2  11386853113.0189  11861199830.8396  13019726211.7369  15156424015.1977
# 3           2880703           2876101           2873457           2866376
# 4  187493855609.345  180763839522.151  189880896903.073  194554483655.528
#
#       2019 [YR2019]     2020 [YR2020]     2021 [YR2021]     2022 [YR2022]  \
# 0  18799444490.1128  19955929052.1496  14266499429.8746  14502158192.0904
# 1          37769499          38972230          40099462          41128771
# 2  15401826127.2539  15162734205.2462  17930565118.8176  18916378860.5488
# 3           2854191           2837849           2811666           2777689
# 4  193459662090.677  164873415325.201  186265418570.697  225560256621.757
#
#       2023 [YR2023]
# 0                ..
# 1          42239854
# 2  22977677860.7979
# 3           2745972
# 4  239899491127.742
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   416 non-null    object
#  1   Country Code   416 non-null    object
#  2   Series Name    416 non-null    object
#  3   1999 [YR1999]  416 non-null    object
#  4   2000 [YR2000]  416 non-null    object
#  5   2001 [YR2001]  416 non-null    object
#  6   2002 [YR2002]  416 non-null    object
#  7   2003 [YR2003]  416 non-null    object
#  8   2004 [YR2004]  416 non-null    object
#  9   2005 [YR2005]  416 non-null    object
#  10  2006 [YR2006]  416 non-null    object
#  11  2007 [YR2007]  416 non-null    object
#  12  2008 [YR2008]  416 non-null    object
#  13  2009 [YR2009]  416 non-null    object
#  14  2010 [YR2010]  416 non-null    object
#  15  2011 [YR2011]  416 non-null    object
#  16  2012 [YR2012]  416 non-null    object
#  17  2013 [YR2013]  416 non-null    object
#  18  2014 [YR2014]  416 non-null    object
#  19  2015 [YR2015]  416 non-null    object
#  20  2016 [YR2016]  416 non-null    object
#  21  2017 [YR2017]  416 non-null    object
#  22  2018 [YR2018]  416 non-null    object
#  23  2019 [YR2019]  416 non-null    object
#  24  2020 [YR2020]  416 non-null    object
#  25  2021 [YR2021]  416 non-null    object
#  26  2022 [YR2022]  416 non-null    object
#  27  2023 [YR2023]  416 non-null    object
# dtypes: object(28)
# memory usage: 91.1+ KB

# %%
# Function to clean column names
def clean_column_name(col):
    if '[' in col and 'YR' in col and ']' in col:
        return col.split(' ')[0]
    return col

# Apply the function to all column names
df.columns = [clean_column_name(col) for col in df.columns]

# Display the cleaned DataFrame columns
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
# Convert all year columns to numeric before melting the DataFrame
years = [str(year) for year in range(1999 , 2024)]
df[years] = df[years].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  416 non-null    object
#  1   Country Code  416 non-null    object
#  2   Series Name   416 non-null    object
#  3   1999          405 non-null    float64
#  4   2000          406 non-null    float64
#  5   2001          407 non-null    float64
#  6   2002          410 non-null    float64
#  7   2003          410 non-null    float64
#  8   2004          410 non-null    float64
#  9   2005          410 non-null    float64
#  10  2006          411 non-null    float64
#  11  2007          411 non-null    float64
#  12  2008          413 non-null    float64
#  13  2009          413 non-null    float64
#  14  2010          413 non-null    float64
#  15  2011          414 non-null    float64
#  16  2012          413 non-null    float64
#  17  2013          413 non-null    float64
#  18  2014          413 non-null    float64
#  19  2015          412 non-null    float64
#  20  2016          411 non-null    float64
#  21  2017          411 non-null    float64
#  22  2018          411 non-null    float64
#  23  2019          410 non-null    float64
#  24  2020          410 non-null    float64
#  25  2021          408 non-null    float64
#  26  2022          404 non-null    float64
#  27  2023          389 non-null    float64
# dtypes: float64(25), object(3)
# memory usage: 91.1+ KB

# %%
# Melt the DataFrame to convert the year columns into rows 
df = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Series Name'], 
                    var_name='Year', value_name='Value')

# %%
df.head()
# Out:
#   Country Name Country Code        Series Name  Year         Value
# 0  Afghanistan          AFG  GDP (current US$)  1999           NaN
# 1  Afghanistan          AFG  Population, total  1999  1.926285e+07
# 2      Albania          ALB  GDP (current US$)  1999  3.212122e+09
# 3      Albania          ALB  Population, total  1999  3.108778e+06
# 4      Algeria          DZA  GDP (current US$)  1999  4.864067e+10

# %%
# Pivot the DataFrame to convert the Series Name column into separate columns 
df = df.pivot(index=['Country Name', 'Country Code', 'Year'], columns='Series Name', values='Value')

# Reset the index of the DataFrame 
df.reset_index(inplace=True)

# %%
df.head()
# Out:
# Series Name Country Name Country Code  Year  GDP (current US$)  \
# 0            Afghanistan          AFG  1999                NaN
# 1            Afghanistan          AFG  2000       3.521418e+09
# 2            Afghanistan          AFG  2001       2.813572e+09
# 3            Afghanistan          AFG  2002       3.825701e+09
# 4            Afghanistan          AFG  2003       4.520947e+09
#
# Series Name  Population, total
# 0                   19262847.0
# 1                   19542982.0
# 2                   19688632.0
# 3                   21000256.0
# 4                   22645130.0

# %%
df.rename(columns={
    'Country Name': 'Country',
    'Country Code': 'Country_Code',
    'Year': 'Year',
    'GDP (current US$)': 'GDP_USD',
    'Population, total': 'Population'
}, inplace=True)

# %%
df.head()
# Out:
# Series Name      Country Country_Code  Year       GDP_USD  Population
# 0            Afghanistan          AFG  1999           NaN  19262847.0
# 1            Afghanistan          AFG  2000  3.521418e+09  19542982.0
# 2            Afghanistan          AFG  2001  2.813572e+09  19688632.0
# 3            Afghanistan          AFG  2002  3.825701e+09  21000256.0
# 4            Afghanistan          AFG  2003  4.520947e+09  22645130.0

# %%
# save the cleaned DataFrame to a new CSV file
df.to_csv('transformed.csv', index=False)
