# %%
import pandas as pd

# %%
df = pd.read_csv('transformed.csv')
df.head()
# Out:
#   Country  Year        GDP_USD  GDP_Capita_USD  Capital_Formation_USD  \
# 0  Brazil  2008  1695860000000            8802           3.666330e+11
# 1  Brazil  2009  1667000000000            8570           3.133310e+11
# 2  Brazil  2010  2208840000000           11249           4.815560e+11
# 3  Brazil  2011  2616160000000           13201           5.710090e+11
# 4  Brazil  2012  2465230000000           12328           5.279830e+11
#
#     Exports_USD   Imports_USD  Industry_Value_Added_USD  Labor_Force  \
# 0  2.295170e+11  2.327320e+11              3.914930e+11     93935308
# 1  1.808920e+11  1.876140e+11              3.647150e+11     95703669
# 2  2.400030e+11  2.629970e+11              5.139520e+11     95367508
# 3  3.030170e+11  3.231450e+11              6.043860e+11     94948394
# 4  2.928080e+11  3.263160e+11              5.456450e+11     97188186
#
#    Military_Exp_USD  Research_GDP_Rate  Trade_GDP_Rate  Unemployment_Rate  \
# ...

# %%
df.head()
# Out:
#   Country  Year        GDP_USD  GDP_Capita_USD  Capital_Formation_USD  \
# 0  Brazil  2008  1695860000000            8802           3.666330e+11
# 1  Brazil  2009  1667000000000            8570           3.133310e+11
# 2  Brazil  2010  2208840000000           11249           4.815560e+11
# 3  Brazil  2011  2616160000000           13201           5.710090e+11
# 4  Brazil  2012  2465230000000           12328           5.279830e+11
#
#     Exports_USD   Imports_USD  Industry_Value_Added_USD  Labor_Force  \
# 0  2.295170e+11  2.327320e+11              3.914930e+11     93935308
# 1  1.808920e+11  1.876140e+11              3.647150e+11     95703669
# 2  2.400030e+11  2.629970e+11              5.139520e+11     95367508
# 3  3.030170e+11  3.231450e+11              6.043860e+11     94948394
# 4  2.928080e+11  3.263160e+11              5.456450e+11     97188186
#
#    Military_Exp_USD  Research_GDP_Rate  Trade_GDP_Rate  Unemployment_Rate  \
# ...

# %%
y = df.GDP_USD
X = df.drop(['GDP_USD', 'Year', 'Country'], axis=1)

# %%
print(X.shape)
print(y.shape)
# Out:
# (256, 12)
# (256,)

# %%
import matplotlib.pyplot as plt

# %%
X.describe()
# Out:
#        GDP_Capita_USD  Capital_Formation_USD   Exports_USD   Imports_USD  \
# count      256.000000           2.500000e+02  2.480000e+02  2.480000e+02
# mean     25349.582031           9.009826e+11  7.576007e+11  7.616644e+11
# std      20500.440006           1.413518e+12  7.645285e+11  8.018373e+11
# min        321.000000           0.000000e+00  5.331911e+09  1.007984e+10
# 25%       5756.750000           1.067212e+11  1.966922e+11  1.850078e+11
# 50%      23091.500000           4.573070e+11  5.494820e+11  5.404380e+11
# 75%      43454.000000           7.602588e+11  8.814018e+11  9.253310e+11
# max      81695.000000           7.715320e+12  3.717890e+12  3.966170e+12
#
#        Industry_Value_Added_USD   Labor_Force  Military_Exp_USD  \
# count              2.490000e+02  2.560000e+02      2.320000e+02
# mean               8.974492e+11  1.233163e+08      8.687913e+10
# std                1.309575e+12  2.053466e+08      1.725610e+11
# ...

# %%
df.isna().sum()
# Out:
# Country                      0
# Year                         0
# GDP_USD                      0
# GDP_Capita_USD               0
# Capital_Formation_USD        6
# Exports_USD                  8
# Imports_USD                  8
# Industry_Value_Added_USD     7
# Labor_Force                  0
# Military_Exp_USD            24
# Research_GDP_Rate           55
# Trade_GDP_Rate               8
# Unemployment_Rate           38
# Pop_Growth_Rate              0
# Population                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# group by year and country and count the avg of gdps
df.groupby(['Country' ])['Population'].sum()
# Out:
# Country
# Brazil                   3288648468
# Canada                    578807753
# China                   22048660000
# Egypt, Arab Rep.         1575099568
# Ethiopia                 1672044848
# France                   1063656674
# Germany                  1315446472
# India                   21219041250
# Iran, Islamic Rep.       1309823830
# Italy                     955460992
# Japan                    2030580232
# Russian Federation       2306672491
# South Africa              890582276
# United Arab Emirates      141232790
# United Kingdom           1042871094
# United States            5135963302
# Name: Population, dtype: int64

# %%
# split the data with 70% in training and 30% in testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# fit a model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# predict
print(model.predict(X_test).head())
print(y_test.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model.fit(X_train, y_train)
#       6 # predict
#       7 print(model.predict(X_test).head())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...
