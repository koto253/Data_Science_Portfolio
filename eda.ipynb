# %%
import pandas as pd

# %%
df = pd.read_csv('transformed.csv')
df.head()
# Out:
#      Country  Year  Word_Population   Exports_USD       GDP_USD  \
# 0  Argentina  1999       6067758458  2.786230e+10  2.835230e+11
# 1  Argentina  1999       6067758459  3.122369e+10  2.842038e+11
# 2  Argentina  1999       6067758460  3.111242e+10  2.686968e+11
# 3  Argentina  1999       6067758461  2.773661e+10  9.772400e+10
# 4  Argentina  1999       6067758462  3.308451e+10  1.275870e+11
#
#    High_Tech_Exports_USD   Imports_USD  Industry_Value_Added_USD  Labor_Force  \
# 0                    NaN  3.276270e+10              7.426497e+10     16410324
# 1                    NaN  3.307015e+10              7.386693e+10     16588444
# 2                    NaN  2.760388e+10              6.782829e+10     16651214
# 3                    NaN  1.306582e+10              2.986224e+10     16491672
# 4                    NaN  1.877290e+10              4.165089e+10     16951795
#
#    Military_Exp_USD  Population_Total  Researchers_per_Million  \
# ...

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Country                       0
# Year                          0
# Word_Population               0
# Exports_USD                  19
# GDP_USD                       0
# High_Tech_Exports_USD       178
# Imports_USD                  19
# Industry_Value_Added_USD      7
# Labor_Force                   0
# Military_Exp_USD             26
# Population_Total              0
# Researchers_per_Million     146
# Unemployment_Rate            67
# dtype: int64

# %%
# Check for data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   450 non-null    object
#  1   Year                      450 non-null    int64
#  2   Word_Population           450 non-null    int64
#  3   Exports_USD               431 non-null    float64
#  4   GDP_USD                   450 non-null    float64
#  5   High_Tech_Exports_USD     272 non-null    float64
#  6   Imports_USD               431 non-null    float64
#  7   Industry_Value_Added_USD  443 non-null    float64
#  8   Labor_Force               450 non-null    int64
#  9   Military_Exp_USD          424 non-null    float64
#  10  Population_Total          450 non-null    int64
#  11  Researchers_per_Million   304 non-null    float64
#  12  Unemployment_Rate         383 non-null    float64
# dtypes: float64(8), int64(4), object(1)
# ...

# %%
# filling missing values with interpolation
columns_to_fill = [
                    'Exports_USD', 'High_Tech_Exports_USD', 'Imports_USD', 
                    'Industry_Value_Added_USD', 'Military_Exp_USD', 
                    'Researchers_per_Million', 'Unemployment_Rate'
                    ]
# Exports_USD
# High_Tech_Exports_USD
# Imports_USD
# Industry_Value_Added_USD
# Military_Exp_USD
# Researchers_per_Million
# Unemployment_Rate


df[columns_to_fill] = df[columns_to_fill].interpolate()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   450 non-null    object
#  1   Year                      450 non-null    int64
#  2   Word_Population           450 non-null    int64
#  3   Exports_USD               450 non-null    float64
#  4   GDP_USD                   450 non-null    float64
#  5   High_Tech_Exports_USD     442 non-null    float64
#  6   Imports_USD               450 non-null    float64
#  7   Industry_Value_Added_USD  450 non-null    float64
#  8   Labor_Force               450 non-null    int64
#  9   Military_Exp_USD          450 non-null    float64
#  10  Population_Total          450 non-null    int64
#  11  Researchers_per_Million   450 non-null    float64
#  12  Unemployment_Rate         450 non-null    float64
# dtypes: float64(8), int64(4), object(1)
# ...

# %%
# filling missing values with mean
df.Exports_USD = df.Exports_USD.fillna(df.Exports_USD.mean())
df.High_Tech_Exports_USD = df.High_Tech_Exports_USD.fillna(df.High_Tech_Exports_USD.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      450 non-null    object
#  1   Year                         450 non-null    int64
#  2   Word_Population              450 non-null    int64
#  3   Exports_USD                  450 non-null    float64
#  4   GDP_USD                      450 non-null    float64
#  5   High_Tech_Exports_USD        450 non-null    float64
#  6   Imports_USD                  450 non-null    float64
#  7   Industry_Value_Added_USD     450 non-null    float64
#  8   Labor_Force                  450 non-null    int64
#  9   Military_Exp_USD             450 non-null    float64
#  10  Population                   450 non-null    int64
#  11  Researchers_per_Million      450 non-null    float64
#  12  Unemployment_Rate            450 non-null    float64
# ...

# %%
# renaming columns population_total to population
df.Population_Total = df.rename(columns={'Population_Total': 'Population'}, inplace=True)

# %%
df.head()
# Out:
#      Country  Year  Word_Population   Exports_USD       GDP_USD  \
# 0  Argentina  1999       6067758458  2.786230e+10  2.835230e+11
# 1  Argentina  1999       6067758459  3.122369e+10  2.842038e+11
# 2  Argentina  1999       6067758460  3.111242e+10  2.686968e+11
# 3  Argentina  1999       6067758461  2.773661e+10  9.772400e+10
# 4  Argentina  1999       6067758462  3.308451e+10  1.275870e+11
#
#    High_Tech_Exports_USD   Imports_USD  Industry_Value_Added_USD  Labor_Force  \
# 0           7.709377e+10  3.276270e+10              7.426497e+10     16410324
# 1           7.709377e+10  3.307015e+10              7.386693e+10     16588444
# 2           7.709377e+10  2.760388e+10              6.782829e+10     16651214
# 3           7.709377e+10  1.306582e+10              2.986224e+10     16491672
# 4           7.709377e+10  1.877290e+10              4.165089e+10     16951795
#
#    Military_Exp_USD  Population  Researchers_per_Million  Unemployment_Rate  \
# ...

# %%
df.drop(columns=['Word_Population'], inplace=True)

# %%
# feature engineering

# Trade Balance
df['Trade_Balance_USD'] = df['Exports_USD'] - df['Imports_USD']

# GDP per Capita
df['GDP_per_Capita_USD'] = round(df['GDP_USD'] / df['Population'], 2)

#Trade GDP Rate 
df['Trade_GDP_Ratio'] = round((df['Exports_USD'] / df['Imports_USD']) * 100, 2)

# Number of Unemployed 
df['Number_of_Unemployed'] = round((df['Unemployment_Rate'] / 100) * df['Population'])

# round off the values of the columns to 2 decimal places
df.Unemployment_Rate = round(df.Unemployment_Rate, 2)

# %%
# changing data types   
df.Number_of_Unemployed = df.Number_of_Unemployed.astype(int)

# %%
df.head(10)
# Out:
#      Country  Year   Exports_USD       GDP_USD  High_Tech_Exports_USD  \
# 0  Argentina  1999  2.786230e+10  2.835230e+11           7.709377e+10
# 1  Argentina  1999  3.122369e+10  2.842038e+11           7.709377e+10
# 2  Argentina  1999  3.111242e+10  2.686968e+11           7.709377e+10
# 3  Argentina  1999  2.773661e+10  9.772400e+10           7.709377e+10
# 4  Argentina  1999  3.308451e+10  1.275870e+11           7.709377e+10
# 5  Argentina  1999  3.926700e+10  1.646579e+11           7.709377e+10
# 6  Argentina  1999  4.619818e+10  1.987371e+11           7.709377e+10
# 7  Argentina  1999  5.355025e+10  2.325573e+11           7.709377e+10
# 8  Argentina  1999  6.516232e+10  2.875305e+11           1.202087e+09
# 9  Argentina  1999  7.976296e+10  3.615580e+11           2.014771e+09
#
#     Imports_USD  Industry_Value_Added_USD  Labor_Force  Military_Exp_USD  \
# 0  3.276270e+10              7.426497e+10     16410324      3.461731e+09
# ...

# %%
df.shape
# Out:
# (450, 16)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Exports_USD', 'GDP_USD', 'High_Tech_Exports_USD',
#        'Imports_USD', 'Industry_Value_Added_USD', 'Labor_Force',
#        'Military_Exp_USD', 'Population', 'Researchers_per_Million',
#        'Unemployment_Rate', 'Trade_Balance_USD', 'GDP_per_Capita_USD',
#        'Trade_GDP_Ratio', 'Number_of_Unemployed'],
#       dtype='object')

# %%
# saving the cleaned data
df.to_csv('cleaned.csv', index=False)

# %%
# ready for modeling    # 1. Data Cleaning and Preprocessing
